# %% [markdown]
# <a href="https://colab.research.google.com/github/jyotinayak321/IBM-training_-learning-/blob/main/cars_without_using_pipelines.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bilkul 👍 Ab **Titanic nahi**, tumhare uploaded **Cars dataset** par same ML preprocessing workflow practice karna hai. Maine dataset check kiya: isme **8128 rows aur 5 columns** hain — `brand`, `km_driven`, `fuel`, `owner`, `selling_price`. Missing values bhi nahi hain.
#
# Is baar main **code nahi dunga**. Tumhe **question-by-question sequence** dunga, jaise teacher practical karwa raha ho. Har question ke baad khud code likhna.
#
# # 🚗 Cars Dataset — ML Practice Questions
#
# ### Step 1 — Dataset Load
#
# **Q1.** CSV file ko Pandas DataFrame mein load karo.
#
# **Q2.** Dataset ki first 5 rows display karo.
#
# **Q3.** Dataset ki last 5 rows display karo.
#
# **Q4.** Dataset ka total number of rows aur columns find karo.
#
# **Q5.** Dataset ke saare column names display karo.
#
# ---
#
# ### Step 2 — Dataset Understanding
#
# **Q6.** Dataset ki complete information check karo.
# Check karo:
#
# * datatype
# * non-null values
# * columns
#
# **Q7.** Numerical columns ka statistical summary nikalo.
#
# **Q8.** Har column mein kitne missing values hain, check karo.
#
# **Q9.** Dataset mein duplicate rows hain ya nahi, check karo.
#
# **Q10.** Har categorical column mein unique values dekho.
#
# ---
#
# # Step 3 — X and y Identify Karo
#
# Ab important question:
#
# **Q11.** Is dataset mein hume **car ki selling price predict** karni hai. Target variable kaunsa column hoga?
#
# **Q12.** `X` aur `y` ko separate karo.
#
# Think:
#
# ```text
# X = ?
# y = ?
# ```
#
# **Q13.** `X` ka shape aur `y` ka shape check karo.
#
# ---
#
# # Step 4 — Train-Test Split
#
# **Q14.** Dataset ko training aur testing data mein divide karo.
#
# Condition:
#
# ```text
# 80% → Training
# 20% → Testing
# ```
#
# **Q15.** `x_train`, `x_test`, `y_train`, `y_test` ke shapes check karo.
#
# **Q16.** Explain karo: **train-test split kyun kiya?**
#
# ---
#
# # Step 5 — Categorical Columns Identify
#
# Ab `X` ko dekho.
#
# **Q17.** `X` mein kaun-kaun se columns categorical hain?
#
# Hint: Dataset ke columns:
#
# ```text
# brand
# km_driven
# fuel
# owner
# ```
#
# **Q18.** Kaunsa column numerical hai?
#
# ---
#
# # Step 6 — Missing Value Check
#
# **Q19.** Training data mein missing values dobara check karo.
#
# **Q20.** Kya is dataset mein missing values hain?
#
# Agar **nahi hain**, to decide karo:
#
# > Kya is dataset mein imputation perform karna zaroori hai?
#
# **Important:** Practice ke liye **missing-value imputation forcefully mat lagana**. Real dataset mein missing values nahi hain, so note that imputation is not required here.
#
# ---
#
# # Step 7 — One-Hot Encoding
#
# Ab main important part 👇
#
# Tumhare categorical columns:
#
# ```text
# brand
# fuel
# owner
# ```
#
# **Q21.** In columns ko One-Hot Encoding ki zaroorat kyun hai?
#
# **Q22.** `OneHotEncoder` import karo.
#
# **Q23.** Encoder create karo using:
#
# ```text
# sparse_output=False
# handle_unknown='ignore'
# ```
#
# **Q24.** `brand` ko One-Hot Encode karo.
#
# Training data par:
#
# ```text
# fit_transform()
# ```
#
# Test data par:
#
# ```text
# transform()
# ```
#
# **Q25.** `fuel` ko One-Hot Encode karo.
#
# **Q26.** `owner` ko One-Hot Encode karo.
#
# ---
#
# # Step 8 — Encoding Check
#
# **Q27.** `brand` encoding ka first 5 rows result dekho.
#
# **Q28.** `fuel` encoding ka first 5 rows result dekho.
#
# **Q29.** `owner` encoding ka first 5 rows result dekho.
#
# **Q30.** Har encoded column ka shape check karo.
#
# Example socho:
#
# ```text
# x_train_brand.shape
# x_train_fuel.shape
# x_train_owner.shape
# ```
#
# ---
#
# # Step 9 — Remaining Numerical Column
#
# Ab categorical columns encode ho chuke hain.
#
# **Q31.** Original `x_train` se encoded categorical columns remove karo.
#
# Kaunse columns remove karne hain?
#
# ```text
# ?
# ?
# ?
# ```
#
# **Q32.** Remaining columns check karo.
#
# Expected important numerical feature:
#
# ```text
# km_driven
# ```
#
# ---
#
# # Step 10 — Combine Features
#
# Ab tumhare paas:
#
# ```text
# Remaining numerical features
#         +
# Encoded brand
#         +
# Encoded fuel
#         +
# Encoded owner
# ```
#
# **Q33.** `np.concatenate()` ka use karke sab training features ko combine karo.
#
# **Q34.** Same transformation test data par perform karo.
#
# **Q35.** `x_train_transformed.shape` check karo.
#
# **Q36.** `x_test_transformed.shape` check karo.
#
# **Q37.** `x_train_transformed[:5]` display karo.
#
# ---
#
# # Step 11 — Model
#
# Ab actual ML model.
#
# **Q38.** Is problem ko identify karo:
#
# ```text
# selling_price
# ```
#
# predict karni hai.
#
# Ye **classification** hai ya **regression**?
#
# **Q39.** Ek suitable regression algorithm import karo.
#
# For practice, use:
#
# ```text
# DecisionTreeRegressor
# ```
#
# **Q40.** Model ka object create karo.
#
# **Q41.** Training data par model fit karo.
#
# ```text
# x_train_transformed
#        +
# y_train
#        ↓
#     MODEL
# ```
#
# ---
#
# # Step 12 — Prediction
#
# **Q42.** Test data ke liye predictions generate karo.
#
# **Q43.** First 10 predictions display karo.
#
# **Q44.** Actual `y_test` ke first 10 values dekho.
#
# Ab compare karo:
#
# ```text
# Actual Price
# vs
# Predicted Price
# ```
#
# ---
#
# # Step 13 — Model Evaluation
#
# ⚠️ Yahan Titanic se difference hai.
#
# Titanic mein tumne:
#
# ```text
# accuracy_score
# ```
#
# use kiya tha.
#
# Lekin Cars mein target **selling_price numerical** hai.
#
# **Q45.** Regression model ke liye kaunse evaluation metrics use kar sakte hain?
#
# Try these:
#
# ```text
# MAE
# MSE
# RMSE
# R² Score
# ```
#
# **Q46.** `mean_absolute_error` calculate karo.
#
# **Q47.** `mean_squared_error` calculate karo.
#
# **Q48.** RMSE calculate karo.
#
# **Q49.** `r2_score` calculate karo.
#
# **Q50.** Apne model ki performance explain karo.
#
# ---
#
# # Step 14 — Model Save
#
# Ab jo tumne Titanic mein pickle kiya tha, wahi practice:
#
# **Q51.** `models` folder create karo.
#
# **Q52.** Trained regression model ko pickle file mein save karo.
#
# Example filename ka decision tum khud karo.
#
# **Q53.** Encoders ko bhi save karo:
#
# ```text
# brand encoder
# fuel encoder
# owner encoder
# ```
#
# **Q54.** Check karo ki `.pkl` files successfully create hui hain ya nahi.
#
# ---
#
# # ⭐ Step 15 — New Car Prediction
#
# Ye **sabse important practice** hai.
#
# Maan lo ek new car hai:
#
# ```text
# brand       = Maruti
# km_driven   = 50000
# fuel        = Petrol
# owner       = First Owner
# ```
#
# ### Q55.
#
# Is new car ka input NumPy array/DataFrame mein banao.
#
# ### Q56.
#
# New car ke `brand` ko trained encoder se transform karo.
#
# **Important:** `fit_transform()` nahi.
#
# Sirf:
#
# ```text
# transform()
# ```
#
# ### Q57.
#
# `fuel` ko trained encoder se transform karo.
#
# ### Q58.
#
# `owner` ko trained encoder se transform karo.
#
# ### Q59.
#
# `km_driven` ko numerical feature ke saath combine karo.
#
# ### Q60.
#
# Final transformed input banao **exactly same feature order mein** jaisa training data mein tha.
#
# ### Q61.
#
# Trained model se selling price predict karo.
#
# Final output:
#
# ```text
# Predicted Selling Price = ?
# ```
#
# ---
#
# # 🧠 Tumhara Complete Workflow
#
# Isko ek baar notebook ke top par likh lo:
#
# ```text
# CSV
#  ↓
# Load Dataset
#  ↓
# Understand Dataset
#  ↓
# X and y
#  ↓
# Train-Test Split
#  ↓
# Identify Categorical Columns
#  ↓
# Check Missing Values
#  ↓
# One-Hot Encoding
#  ↓
# Remove Original Categorical Columns
#  ↓
# Concatenate Features
#  ↓
# Train Regression Model
#  ↓
# Predict
#  ↓
# MAE / MSE / RMSE / R²
#  ↓
# Save Model + Encoders
#  ↓
# New Car Input
#  ↓
# Same Preprocessing
#  ↓
# Predict Selling Price
# ```
#
# ### 🎯 Practice ka rule
#
# **Main tumhe abhi answers/code nahi dunga.** Tum **Q1 se start karo**, code likho aur output mujhe bhejo. Main check karke bataunga **correct hai ya nahi**, phir tumhe **next question** dunga.
#
# Isse tumhara actual practical strong hoga, sirf code yaad nahi hoga.
