# %% [markdown]
# <a href="https://colab.research.google.com/github/jyotinayak321/IBM-training_-learning-/blob/main/Panda_DATAFRAME.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
d = {"product":["a","B","C","D","E"],
     "Amount": [1,2,3,4,np.nan]}              #NAN is data missing value
d
# Out:
# {'product': ['a', 'B', 'C', 'D', 'E'], 'Amount': [1, 2, 3, 4, nan]}

# %%
# create a DataFrame
df = pd.DataFrame(d)

# %%
df["New_Col"] = np.nan
df
# Out:
#   product  Amount  New_Col
# 0       a     1.0      NaN
# 1       B     2.0      NaN
# 2       C     3.0      NaN
# 3       D     4.0      NaN
# 4       E     NaN      NaN

# %%
df.columns
# Out:
# Index(['product', 'Amount', 'New_Col'], dtype='object')

# %%
df.drop(columns="New_Col", inplace=True)
df.columns
# Out:
# Index(['product', 'Amount'], dtype='object')

# %%
df.rename(columns= {"Product":"Item"},inplace=True)

# %%
df.columns
# Out:
# Index(['product', 'Amount'], dtype='object')

# %%
df.rename(columns={"Amount": "Price"}, inplace=True)

# %%
df.columns
# Out:
# Index(['product', 'Price'], dtype='object')

# %%
df["Price"].fillna(200, inplace=True)
# Out:
# /tmp/ipykernel_1337/667004765.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Price"].fillna(200, inplace=True)
# /tmp/ipykernel_1337/667004765.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Price"].fillna(200, inplace=True)

# %%
df = df[["Price", "product"]]

# %%
df["Price"].iloc[3]=0
df
# Out:
# /tmp/ipykernel_1337/1119535683.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["Price"].iloc[3]=0
# /tmp/ipykernel_1337/1119535683.py:1: SettingWithCopyWarning:
# ...

# %%
df["Location"] = ["Delhi", "Mumbai", "Chennai", "Kolkata", "Bangalore"]

# %%
len(df)
# Out:
# 5

# %%
df.shape # it will shows the shape of the df
# Out:
# (5, 3)

# %%
df  # it will show your dataframe work
# Out:
#    Price product   Location
# 0    1.0       a      Delhi
# 1    2.0       B     Mumbai
# 2    3.0       C    Chennai
# 3    0.0       D    Kolkata
# 4  200.0       E  Bangalore

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.head()
# Out:
#    Price product   Location
# 0    1.0       a      Delhi
# 1    2.0       B     Mumbai
# 2    3.0       C    Chennai
# 3    0.0       D    Kolkata
# 4  200.0       E  Bangalore

# %%
df.tail()
# Out:
#    Price product   Location
# 0    1.0       a      Delhi
# 1    2.0       B     Mumbai
# 2    3.0       C    Chennai
# 3    0.0       D    Kolkata
# 4  200.0       E  Bangalore

# %%
pd.set_option('display.max_columns',None)

# %%
df = pd.read_excel("SuperStore.xls")   #loading dataset

# %%
df
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0           1  US-2023-103800 2023-01-03 2023-01-07  Standard Class
# 1           2  US-2023-112326 2023-01-04 2023-01-08  Standard Class
# 2           3  US-2023-112326 2023-01-04 2023-01-08  Standard Class
# 3           4  US-2023-112326 2023-01-04 2023-01-08  Standard Class
# 4           5  US-2023-141817 2023-01-05 2023-01-12  Standard Class
# ...       ...             ...        ...        ...             ...
# 10189   10190  US-2026-143259 2026-12-30 2027-01-03  Standard Class
# 10190   10191  US-2026-115427 2026-12-30 2027-01-03  Standard Class
# 10191   10192  US-2026-156720 2026-12-30 2027-01-03  Standard Class
# 10192   10193  US-2026-143259 2026-12-30 2027-01-03  Standard Class
# 10193   10194  CA-2026-143500 2026-12-30 2027-01-03  Standard Class
#
#       Customer ID      Customer Name      Segment Country/Region  \
# 0        DP-13000      Darren Powers     Consumer  United States
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State/Province', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.info()  # symmery of dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10194 non-null  int64
#  1   Order ID        10194 non-null  object
#  2   Order Date      10194 non-null  datetime64[ns]
#  3   Ship Date       10194 non-null  datetime64[ns]
#  4   Ship Mode       10194 non-null  object
#  5   Customer ID     10194 non-null  object
#  6   Customer Name   10194 non-null  object
#  7   Segment         10194 non-null  object
#  8   Country/Region  10194 non-null  object
#  9   City            10194 non-null  object
#  10  State/Province  10194 non-null  object
#  11  Postal Code     10194 non-null  object
#  12  Region          10194 non-null  object
#  13  Product ID      10194 non-null  object
#  14  Category        10194 non-null  object
#  15  Sub-Category    10194 non-null  object
# ...

# %%
df.head(2)  # we use head for specific top 5 but as we menton the top 2
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  US-2023-103800 2023-01-03 2023-01-07  Standard Class    DP-13000
# 1       2  US-2023-112326 2023-01-04 2023-01-08  Standard Class    PO-19195
#
#    Customer Name      Segment Country/Region        City State/Province  \
# 0  Darren Powers     Consumer  United States     Houston          Texas
# 1  Phillina Ober  Home Office  United States  Naperville       Illinois
#
#   Postal Code   Region       Product ID         Category Sub-Category  \
# 0       77095  Central  OFF-PA-10000174  Office Supplies        Paper
# 1       60540  Central  OFF-BI-10004094  Office Supplies      Binders
#
#                                         Product Name   Sales  Quantity  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...  16.448         2
# 1         GBC Standard Plastic Binding Systems Combs   3.540         2
#
#    Discount  Profit
# 0       0.2  5.5512
# 1       0.8 -5.4870

# %%
df.tail(2)   # we use  the tail for the bottom top 5 but and as we want speciafic value
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 10192   10193  US-2026-143259 2026-12-30 2027-01-03  Standard Class
# 10193   10194  CA-2026-143500 2026-12-30 2027-01-03  Standard Class
#
#       Customer ID      Customer Name   Segment Country/Region           City  \
# 10192    PO-18865  Patrick O'Donnell  Consumer  United States  New York City
# 10193    HO-15230        Harry Olson  Consumer         Canada  Charlottetown
#
#              State/Province Postal Code Region       Product ID  \
# 10192              New York       10009   East  TEC-PH-10004774
# 10193  Prince Edward Island         C0A   East  OFF-BI-10004040
#
#               Category Sub-Category                 Product Name   Sales  \
# 10192       Technology       Phones    Gear Head AU3700S Headset  90.930
# 10193  Office Supplies      Binders  Wilson Jones Impact Binders   3.024
#
#        Quantity  Discount  Profit
# 10192         7       0.0  2.7279
# 10193         3       0.2 -0.6048

# %%
df.sample(15)
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 5178     5179  US-2025-156685 2025-07-08 2025-07-10    Second Class
# 825       826  US-2023-169019 2023-07-26 2023-07-30  Standard Class
# 6381     6382  US-2025-163881 2025-11-24 2025-11-30  Standard Class
# 5446     5447  US-2025-158001 2025-08-23 2025-08-27  Standard Class
# 1267     1268  US-2023-108189 2023-10-02 2023-10-05     First Class
# 10074   10075  US-2026-115931 2026-12-22 2026-12-26  Standard Class
# 2619     2620  US-2024-100818 2024-05-31 2024-06-05    Second Class
# 322       323  US-2023-102988 2023-04-05 2023-04-09    Second Class
# 2382     2383  US-2024-133837 2024-04-13 2024-04-18  Standard Class
# 5002     5003  US-2025-147375 2025-06-12 2025-06-14    Second Class
# 9798     9799  US-2026-118017 2026-12-03 2026-12-06    Second Class
# 5825     5826  US-2025-125402 2025-09-25 2025-10-01  Standard Class
# 6258     6259  US-2025-121370 2025-11-14 2025-11-19    Second Class
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State/Province', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df["Ship Mode"].unique()      #find all unique (distinct) values in a column
# Out:
# array(['Standard Class', 'First Class', 'Second Class', 'Same Day'],
#       dtype=object)

# %%
df["Ship Mode"].value_counts()   #counts how many times each unique value appears
# Out:
# Ship Mode
# Standard Class    6120
# Second Class      1979
# First Class       1548
# Same Day           547
# Name: count, dtype: int64

# %%
df.sample(3)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 352      353  US-2023-102715 2023-04-11 2023-04-13    Second Class
# 5725    5726  US-2025-162159 2025-09-16 2025-09-18     First Class
# 8144    8145  US-2026-105046 2026-07-17 2026-07-23  Standard Class
#
#      Customer ID Customer Name      Segment Country/Region      City  \
# 352     JK-15370    Jay Kimmel     Consumer  United States     Miami
# 5725    CR-12625   Corey Roper  Home Office  United States  Columbus
# 8144    BE-11335   Bill Eplett  Home Office  United States      Rome
#
#      State/Province Postal Code Region       Product ID    Category  \
# 352         Florida       33180  South  TEC-AC-10001874  Technology
# 5725        Georgia       31907  South  FUR-CH-10001146   Furniture
# 8144       New York       13440   East  FUR-FU-10004848   Furniture
#
#      Sub-Category                                       Product Name    Sales  \
# ...

# %%
df["Customer ID"]
# Out:
# 0        DP-13000
# 1        PO-19195
# 2        PO-19195
# 3        PO-19195
# 4        MB-18085
#            ...
# 10189    PO-18865
# 10190    EB-13975
# 10191    JM-15580
# 10192    PO-18865
# 10193    HO-15230
# Name: Customer ID, Length: 10194, dtype: object

# %%
df["Customer ID"].unique()
# Out:
# array(['DP-13000', 'PO-19195', 'MB-18085', 'ME-17320', 'JO-15145',
#        'LS-17230', 'VS-21820', 'MS-17830', 'AJ-10780', 'SV-20365',
#        'BD-11605', 'ND-18370', 'MM-17920', 'CS-12250', 'BS-11590',
#        'EH-13990', 'DL-13315', 'DW-13195', 'TS-21340', 'HL-15040',
#        'XP-21865', 'MV-17485', 'MM-18280', 'TB-21400', 'JW-15220',
#        'SG-20605', 'IM-15055', 'CA-11965', 'SD-20485', 'EJ-13720',
#        'JC-15340', 'MV-18190', 'LC-17050', 'BD-11500', 'EB-13930',
#        'CD-12790', 'MH-17440', 'DB-13270', 'ND-18460', 'CK-12760',
#        'NM-18445', 'GA-14725', 'NF-18385', 'SC-20095', 'ML-17395',
#        'ST-20530', 'BF-11020', 'MN-17935', 'TB-21595', 'AB-10015',
#        'LC-16930', 'SR-20740', 'TM-21010', 'SA-20830', 'MG-17875',
#        'JH-15430', 'JS-16030', 'VF-21715', 'SC-20380', 'DB-13060',
#        'GW-14605', 'HR-14770', 'KN-16705', 'NH-18610', 'JS-15595',
#        'EJ-14155', 'SC-20020', 'AJ-10945', 'AP-10720', 'CL-12565',
# ...

# %%
df.sample(5)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2702    2703  US-2024-118955 2024-06-16 2024-06-20  Standard Class
# 3036    3037  US-2024-139584 2024-08-24 2024-08-28  Standard Class
# 4107    4108  US-2024-158456 2024-12-24 2024-12-29  Standard Class
# 948      949  US-2023-124737 2023-08-23 2023-08-27  Standard Class
# 5651    5652  US-2025-103709 2025-09-08 2025-09-15  Standard Class
#
#      Customer ID     Customer Name    Segment Country/Region           City  \
# 2702    LS-17230  Lycoris Saunders   Consumer  United States  Grand Prairie
# 3036    EM-13810     Eleni McCrary  Corporate  United States  New York City
# 4107    KT-16465     Kean Takahito   Consumer  United States    Los Angeles
# 948     AP-10915    Arthur Prichep   Consumer  United States         Denver
# 5651    LP-17095         Liz Preis   Consumer  United States        Visalia
#
#      State/Province Postal Code   Region       Product ID         Category  \
# ...

# %%
df["Region"]
# Out:
# 0        Central
# 1        Central
# 2        Central
# 3        Central
# 4           East
#           ...
# 10189       East
# 10190       West
# 10191       West
# 10192       East
# 10193       East
# Name: Region, Length: 10194, dtype: object

# %%
df["Region"].unique()
# Out:
# array(['Central', 'East', 'South', 'West'], dtype=object)

# %%
df["Region"].value_counts()
# Out:
# Region
# West       3253
# East       2986
# Central    2335
# South      1620
# Name: count, dtype: int64

# %%
df.sample(5)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9036    9037  US-2026-151596 2026-10-08 2026-10-11     First Class
# 1668    1669  US-2023-157385 2023-11-23 2023-11-25     First Class
# 982      983  US-2023-101266 2023-08-27 2023-08-30    Second Class
# 1744    1745  US-2023-121629 2023-11-28 2023-12-02  Standard Class
# 8502    8503  US-2026-157987 2026-09-02 2026-09-06  Standard Class
#
#      Customer ID   Customer Name    Segment Country/Region           City  \
# 9036    BP-11050      Barry Pond  Corporate  United States       Cranston
# 1668    SC-20095    Sanjit Chand   Consumer  United States    Los Angeles
# 982     MM-17920   Michael Moore   Consumer  United States    Springfield
# 1744    BT-11680  Brian Thompson   Consumer  United States        Houston
# 8502    AC-10615       Ann Chong  Corporate  United States  New York City
#
#      State/Province Postal Code   Region       Product ID         Category  \
# ...

# %%
df["Category"]
# Out:
# 0        Office Supplies
# 1        Office Supplies
# 2        Office Supplies
# 3        Office Supplies
# 4        Office Supplies
#               ...
# 10189    Office Supplies
# 10190    Office Supplies
# 10191    Office Supplies
# 10192         Technology
# 10193    Office Supplies
# Name: Category, Length: 10194, dtype: object

# %%
df["Category"].unique()
# Out:
# array(['Office Supplies', 'Furniture', 'Technology'], dtype=object)

# %%
df["Category"].value_counts()
# Out:
# Category
# Office Supplies    6128
# Furniture          2201
# Technology         1865
# Name: count, dtype: int64

# %%
df.sample(6)  #does not follow the original sequence because it is designed to return random rowsand as i speciafilly
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9250    9251  US-2026-117114 2026-10-31 2026-11-05  Standard Class
# 5328    5329  US-2025-137743 2025-07-30 2025-08-04  Standard Class
# 5655    5656  US-2025-108987 2025-09-08 2025-09-10    Second Class
# 9724    9725  US-2026-135860 2026-12-01 2026-12-07  Standard Class
# 5381    5382  US-2025-155845 2025-08-12 2025-08-15    Second Class
# 9330    9331  US-2026-118213 2026-11-05 2026-11-07     First Class
#
#      Customer ID     Customer Name      Segment Country/Region        City  \
# 9250    CY-12745      Craig Yedwab    Corporate  United States     Chicago
# 5328    KH-16360  Katherine Hughes     Consumer  United States     Chicago
# 5655    AG-10675       Anna Gayman     Consumer  United States     Houston
# 9724    JH-15985       Joseph Holt     Consumer  United States     Saginaw
# 5381    CM-12235      Chris McAfee     Consumer  United States  Carrollton
# ...

# %%
df[df["Order Date"].dt.year==2023]  #This filters the DataFrame and keeps only the rows where the year is 2023.
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  US-2023-103800 2023-01-03 2023-01-07  Standard Class
# 1          2  US-2023-112326 2023-01-04 2023-01-08  Standard Class
# 2          3  US-2023-112326 2023-01-04 2023-01-08  Standard Class
# 3          4  US-2023-112326 2023-01-04 2023-01-08  Standard Class
# 4          5  US-2023-141817 2023-01-05 2023-01-12  Standard Class
# ...      ...             ...        ...        ...             ...
# 2046    2047  US-2023-111150 2023-12-31 2024-01-04  Standard Class
# 2047    2048  US-2023-143231 2023-12-31 2024-01-03     First Class
# 2048    2049  US-2023-133592 2023-12-31 2024-01-07  Standard Class
# 2049    2050  US-2023-157644 2023-12-31 2024-01-01     First Class
# 2050    2051  US-2023-133949 2023-12-31 2023-12-31        Same Day
#
#      Customer ID     Customer Name      Segment Country/Region           City  \
# 0       DP-13000     Darren Powers     Consumer  United States        Houston
# ...

# %%
df[df["Order Date"].dt.year==2023]["Order Date"]
#Filters the DataFrame to keep only rows where the year is 2023.
#Selects only the "Order Date" column from those filtered rows.
# Out:
# 0      2023-01-03
# 1      2023-01-04
# 2      2023-01-04
# 3      2023-01-04
# 4      2023-01-05
#           ...
# 2046   2023-12-31
# 2047   2023-12-31
# 2048   2023-12-31
# 2049   2023-12-31
# 2050   2023-12-31
# Name: Order Date, Length: 2051, dtype: datetime64[ns]

# %%
df[df["Order Date"].dt.year==2023]["Order Date"].dt.year.unique()

         #.unique() when you want the distinct value
# Out:
# array([2023], dtype=int32)

# %%
df[df["Order Date"].dt.year==2023]["Order Date"].dt.month.value_counts()

#.value_counts() when you want both the distinct values and how many times
# Out:
# Order Date
# 11    320
# 12    297
# 9     273
# 10    168
# 3     159
# 8     158
# 7     143
# 6     136
# 4     135
# 5     132
# 1      84
# 2      46
# Name: count, dtype: int64

# %% [markdown]
# df["Customer ID"].value_counts()   #counts how many times each unique value appears
