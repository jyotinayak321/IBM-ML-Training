# %% [markdown]
# <a href="https://colab.research.google.com/github/jyotinayak321/IBM-ML-Training/blob/main/K_Mean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
from sklearn.cluster import KMeans
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Data
data = np.array([
    [20, 80],
    [25, 85],
    [30, 90],
    [100, 20],
    [110, 25],
    [120, 30],
    [43,120]
])

# Apply K-Means
kmeans = KMeans(n_clusters=2, random_state=42)
clusters = kmeans.fit_predict(data)

# Print clusters
print("Cluster Assignment:",clusters)
print("cluster cennters:",Kmeans.cluster_centers_)

# Plot data points
plt.scatter(data[:, 0], data[:, 1], c=clusters)

# Plot cluster centers
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], marker='X', s=200)
# Out:
# Cluster Assignment: [0 0 0 1 1 1 0]
# cluster cennters: [[100.    25.  ]
#  [ 28.75  88.25]]
